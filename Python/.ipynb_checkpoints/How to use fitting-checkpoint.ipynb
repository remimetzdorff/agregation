# %%
# %pylab qt
# %matplotlib inline
import fitting
import pandas

x = np.linspace(0, 2*np.pi, 1001)
y = np.sin(2*np.pi*0.01*x)

plt.plot(x, y, "o")

func = fitting.Fit()
fit_params = func.fit(func.sin, x, y)
plt.plot(x, func.sin(x, *fit_params))

print(fit_params)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-30a59735731f> in <module>
#       9 plt.plot(x, y, "o")
#      10
# ---> 11 func = fitting.Fit()
#      12 fit_params = func.fit(func.sin, x, y)
#      13 plt.plot(x, func.sin(x, *fit_params))
#
# TypeError: __init__() missing 1 required positional argument: 'func'

# %%
n = 3648
x = (np.arange(n)-n/2)*8e-6
y = (np.cos(2*np.pi*5000*x+np.pi)+1) * func.gaussian(x, 0, 0.005, 1)

plt.plot(x*1e3, y, "o")

data = pandas.Series(y, index=x)
center = 0
span = 2e-3
new_data = data[center-span/2:center+span/2]
plt.plot(new_data.index.values*1e3, new_data.values)

func = fitting.Fit()
fit_params = func.fit(func.sin, new_data.index, new_data.values)
plt.plot(x*1e3, func.sin(x, *fit_params))

plt.xlim(-2,2)
# Out:
# (-2, 2)

# %%
import scipy.constants as cst

e = 7.53e-19
nu = e/cst.h
wavelength = cst.c/nu
print(wavelength*1e9)
# Out:
# 263.8042263176306
