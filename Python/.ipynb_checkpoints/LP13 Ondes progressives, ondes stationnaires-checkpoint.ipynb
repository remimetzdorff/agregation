# %%
# %pylab qt
# %matplotlib inline

import scipy.constants as cst

def mysavefig(name):
    plt.tight_layout()
    plt.savefig(name, bbox_inches="tight", dpi=200)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.figure(figsize=(8,6))
sps = (2,1)
ax1 = plt.subplot2grid(sps, (0,0))
ax2 = plt.subplot2grid(sps, (1,0))

omega = 2*np.pi
k = 1.5*2*np.pi

x = np.linspace(0,1, 1001)
time = [0.25]

for i, t in enumerate(time):
    ax1 = plt.subplot2grid(sps, (0,0))
    ax2 = plt.subplot2grid(sps, (1,0))
    ax3 = plt.subplot2grid(sps, (2,0))

    ax1.plot(x, np.sin(k*x)*np.cos(omega*t), "C0")
    ax2.plot(x, (np.sin(k*x)*np.sin(omega*t))**2, "C1")
    ax2.plot(x, (np.cos(k*x)*np.cos(omega*t))**2, "C2")
    
    ax1.set_ylim(-1.1,1.1)
    ax2.set_ylim(-0.1,1.1)
    for ax in [ax1, ax2]:
        ax.set_xlim(-0.1,1.1)
