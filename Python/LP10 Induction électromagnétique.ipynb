# %%
# %pylab qt
# %matplotlib inline

import scipy.constants as cst

def mysavefig(name):
    plt.tight_layout()
    plt.savefig(name, bbox_inches="tight", dpi=200)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.figure(figsize=(8,6))

def inductance(n, s=25e-3, l=5e-2):
    return cst.mu_0 * n**2 * s/l

n = np.arange(1000)
plt.plot(n, inductance(n))
N = np.array([125,250,500,1000])
plt.plot(N, inductance(N), "o")
plt.xlabel("Nombre de spires")
plt.ylabel("Inducance (H)")
# Out:
# Text(0, 0.5, 'Inducance (H)')
