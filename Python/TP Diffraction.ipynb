# %%
# %pylab qt
# %matplotlib inline
import pandas
import fitting
func = fitting.Fit()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = np.linspace(-1,1,1001)
plt.plot(x, func.sinc(x,0,2,1,0))
plt.plot(x, func.sinc_squarred(x,0,2,1,0))
# Out:
# C:\Users\remi\Documents\Agreg\Python\fitting.py:84: RuntimeWarning: invalid value encountered in true_divide
#   return offset + scale*np.sin(X)/X

# %%
file = "C:/Users/remi/Documents/Agreg/Python/TP_diffraction.txt"
y = np.loadtxt(file)/2**16
x = (np.arange(len(y))-len(y)/2)*8e-6

autoguess_params = func.guess_params("sinc_squarred", x,y)
plt.plot(x*1e3,y)

plt.plot(x*1e3, func.sinc_squarred(x, *autoguess_params))
print (autoguess_params)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-2d34e4d8a4d6> in <module>
#       3 x = (np.arange(len(y))-len(y)/2)*8e-6
#       4
# ----> 5 autoguess_params = func.guess_params("sinc_squarred", x,y)
#       6 plt.plot(x*1e3,y)
#       7
#
# TypeError: guess_params() takes 3 positional arguments but 4 were given

# %%
plt.plot(x*1e3,y)
guess_params = [-0.0008, 105.73508517374722, 0.82, 0.0184783935546875]
plt.plot(x*1e3, func.sinc_squarred(x, *guess_params))

# %%
plt.figure(1, figsize=(8,6))

fit_params = func.fit(func.sinc_squarred, x, y, manualguess_params=guess_params)
plt.plot(x*1e3,y)
plt.plot(x*1e3, func.sinc_squarred(x, *fit_params))

plt.xlabel("Position (mm)")
plt.ylabel(r"Intensité relative")
# Out:
# Text(0, 0.5, 'Intensité relative')

# %%
print(len(x))
# Out:
# 3648
